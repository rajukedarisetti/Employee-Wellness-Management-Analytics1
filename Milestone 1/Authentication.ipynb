# %%
import smtplib, re
import random
from email.mime.text import MIMEText

sender = "satishkedarisetti140@gmail.com"
app_password = "kqizqjnnqoupeyha"

# Email Validation Function

def is_valid_email(email):
    pattern = r'^[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}$'
    return re.fullmatch(pattern, email) is not None

# Keep Asking Until Valid Email

while True:
    receiver = input("Enter your Email: ").strip()

    if is_valid_email(receiver):
        break
    else:
        print("❌ Invalid Email Address! Please enter a valid email.\n")

otp = random.randint(100000,999999)

msg = MIMEText(f"Your OTP is {otp}")
msg["Subject"] = "MoodMentor OTP"
msg["From"] = sender
msg["To"] = receiver

server = smtplib.SMTP("smtp.gmail.com",587)
server.starttls()
server.login(sender, app_password)
server.sendmail(sender, receiver, msg.as_string())
server.quit()

print("OTP Sent!")
print("OTP =", otp)

entered_otp = input("Enter the OTP received in your email: ")

if entered_otp == str(otp):
    print("✅ Email Verified Successfully!")
else:
    print("❌ Invalid OTP")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1398/300067879.py in <cell line: 0>()
#      15
#      16 while True:
# ---> 17     receiver = input("Enter your Email: ").strip()
#      18
#      19     if is_valid_email(receiver):
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
import jwt
from datetime import datetime, timedelta, UTC

SECRET_KEY = "MoodMentor123456789012345678901234567890"
# For HS256, the recommended secret key length is at least 32 bytes.

payload = {
    "email": receiver,
    "exp": datetime.now(UTC) + timedelta(hours=1)
}

token = jwt.encode(payload, SECRET_KEY, algorithm="HS256")

print("JWT Token:")
print(token)
# Out:
# JWT Token:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6InNwcmluZ2JvYXJkbWVudG9yNzg2QGdtYWlsLmNvbSIsImV4cCI6MTc4MzAwMDM1NH0.RY94JTp1-PzJyskwrb5fyN_r58ffUmKRnZA25mjkFqE

# %%
try:
    decoded = jwt.decode(token, SECRET_KEY, algorithms=["HS256"])
    print("Token is Valid")
    print(decoded)
except jwt.ExpiredSignatureError:
    print("Token Expired")
except jwt.InvalidTokenError:
    print("Invalid Token")
# Out:
# Token is Valid
# {'email': 'springboardmentor786@gmail.com', 'exp': 1783000354}

# %%
# !pip install streamlit   --q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 57.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 94.6 MB/s eta 0:00:00

# %%
# %%writefile app.py
import streamlit as st

st.set_page_config(
    page_title="MoodMentor",
    page_icon="😊",
    layout="centered"
)

st.title("😊 MoodMentor")

st.subheader("AI-Powered Emotional Wellness System")

choice = st.sidebar.selectbox(
    "Menu",
    ["Home", "Register", "Login"]
)

if choice == "Home":
    st.write("Welcome to MoodMentor")

elif choice == "Register":
    st.header("Register")

elif choice == "Login":
    st.header("Login")

st.header("Create Account")

email = st.text_input("Email")

password = st.text_input(
    "Password",
    type="password"
)

confirm = st.text_input(
    "Confirm Password",
    type="password"
)

if st.button("Send OTP"):
    st.success("OTP Sent")

otp = st.text_input("Enter OTP")

if st.button("Verify OTP"):
    st.success("Email Verified")

st.header("Login")

login_email = st.text_input("Email")

login_password = st.text_input(
    "Password",
    type="password"
)

if st.button("Login"):
    st.success("JWT Generated")

st.title("Dashboard")

st.success("Welcome!")

st.metric("Current Mood", "😊 Happy")

st.metric("Sentiment", "Positive")

menu = st.sidebar.radio(
    "Navigation",
    [
        "Home",
        "Analyze",
        "History",
        "Profile",
        "Logout"
    ]
)

if st.button("Login"):
    if login(email, password):
        st.success("Login Successful")
        st.session_state["logged_in"] = True
    else:
        st.error("Invalid Email or Password")
# Out:
# Overwriting app.py

# %%
# !pip install -q  pyngrok

# %%
from pyngrok import ngrok

# Set your auth token
ngrok.set_auth_token("3FqnPrgH4oolsScmhs8DHFPKDnh_5iaDZMmHFSUHX8gDYjoRm")

# %%
from pyngrok import ngrok
# !streamlit run app.py &>/content/logs.txt &
public_url = ngrok.connect(8501)
print("Streamlit Public URL:", public_url)
# Out:
# Streamlit Public URL: NgrokTunnel: "https://cognately-evocative-cristin.ngrok-free.dev" -> "http://localhost:8501"
